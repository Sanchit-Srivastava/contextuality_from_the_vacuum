# %% [markdown]
# # Paper plots
#
# > This notebook generates the plots as they appear in the paper.

# %%
import sys, os, warnings
from pathlib import Path

# Ensure src/ is importable
for p in [Path.cwd(), *Path.cwd().parents]:
    cand = p / "src"
    if cand.exists():
        sys.path.insert(0, str(cand))
        break

# Ensure scripts/ is importable (for plot_definitions)
for p in [Path.cwd(), *Path.cwd().parents]:
    cand = p / "scripts"
    if cand.exists():
        sys.path.insert(0, str(cand))
        break

warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["DejaVu Serif", "Bitstream Vera Serif", "Computer Modern Roman"],
    "mathtext.fontset": "cm",
})

from plot_definitions import PLOTS

OUTPUT_DIR = "output"

# %% [markdown]
# ## Contextual fraction vs gap (R/T=1, large detectors)

# %%
PLOTS['cf_large'][0](OUTPUT_DIR, use_latex=False)
plt.show()

# %% [markdown]
# ## Contextual fraction vs gap (R/T=0.1, small detectors)

# %%
PLOTS['cf_small'][0](OUTPUT_DIR, use_latex=False)
plt.show()

# %% [markdown]
# ## Wigner negativity vs gap (R/T=1)

# %%
PLOTS['wigner_large'][0](OUTPUT_DIR, use_latex=False)
plt.show()

# %% [markdown]
# ## Wigner negativity vs gap (R/T=0.1, small detectors)

# %%
PLOTS['wigner_small'][0](OUTPUT_DIR, use_latex=False)
plt.show()

# %% [markdown]
# ## CF, SU(2) vs HW (R/T=0.1, appendix)

# %%
PLOTS['cf_appendix'][0](OUTPUT_DIR, use_latex=False)
plt.show()

# %% [markdown]
# ## Wigner negativity, SU(2) vs HW (R/T=0.1, appendix)

# %%
PLOTS['wigner_appendix'][0](OUTPUT_DIR, use_latex=False)
plt.show()

# %% [markdown]
# ## CF vs gap, fixed RΩ=0.01, dΩ=20 (appendix C)

# %%
PLOTS['cf_fixed_romega'][0](OUTPUT_DIR, use_latex=False)
plt.show()

# %% [markdown]
# ## Wigner negativity vs gap, fixed RΩ=0.01, dΩ=20 (appendix C)

# %%
PLOTS['wigner_fixed_romega'][0](OUTPUT_DIR, use_latex=False)
plt.show()
